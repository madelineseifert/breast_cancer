# %%
from sklearn import tree
import pandas as pd
import os

# %%
data_path = "data.csv"
cancer_df = pd.read_csv(data_path, encoding="ISO-8859-1")

# %%
df = cancer_df.drop(['Unnamed: 32'], axis=1)

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
target = df["diagnosis"]
target_names = ["negative", "positive"]

# %%
data = df.drop("diagnosis", axis=1)
feature_names = data.columns
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
data_final = data.drop("id", axis=1)
feature_names = data_final.columns
data_final.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_final, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9370629370629371

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.972027972027972

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.12473126366989434, 'radius_worst'),
#  (0.12134911600055764, 'concave points_worst'),
#  (0.11738962423380545, 'area_worst'),
#  (0.10445950862094508, 'concave points_mean'),
#  (0.09727331936089952, 'perimeter_worst'),
#  (0.056748646189401765, 'area_mean'),
#  (0.04592722211855732, 'area_se'),
#  (0.04342522467019111, 'perimeter_mean'),
#  (0.03772606309059543, 'concavity_worst'),
#  (0.03172945555149545, 'radius_mean'),
#  (0.02729900579792418, 'concavity_mean'),
#  (0.02230665429549296, 'radius_se'),
#  (0.020070428089720472, 'texture_worst'),
#  (0.01904859445170235, 'perimeter_se'),
#  (0.017390560337967043, 'compactness_worst'),
#  (0.01687919907958535, 'texture_mean'),
#  (0.014711337590667775, 'symmetry_worst'),
#  (0.013200318251762554, 'smoothness_worst'),
#  (0.010782802880022771, 'compactness_mean'),
#  (0.0068014973687781964, 'concavity_se'),
#  (0.006361715457813825, 'fractal_dimension_se'),
#  (0.006092821103210015, 'smoothness_mean'),
# ...
