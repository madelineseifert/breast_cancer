# %%
from sklearn import tree
import pandas as pd
import os

# %%
data_path = "data.csv"
cancer_df = pd.read_csv(data_path, encoding="ISO-8859-1")

# %%
df = cancer_df.drop(['Unnamed: 32'], axis=1)

# %%
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#             ...             radius_worst  texture_worst  perimeter_worst  \
# 0           ...                    25.38          17.33           184.60
# 1           ...                    24.99          23.41           158.80
# 2           ...                    23.57          25.53           152.50
# 3           ...                    14.91          26.50            98.87
# 4           ...                    22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
target = df["diagnosis"]
target_names = ["negative", "positive"]

# %%
data = df.drop("diagnosis", axis=1)
feature_names = data.columns
data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# 0         0.2419           ...                    25.38          17.33
# 1         0.1812           ...                    24.99          23.41
# 2         0.2069           ...                    23.57          25.53
# 3         0.2597           ...                    14.91          26.50
# 4         0.1809           ...                    22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9370629370629371

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.965034965034965

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.14696349866460076, 'concave points_worst'),
#  (0.14054022974677322, 'concave points_mean'),
#  (0.10710242447079463, 'perimeter_worst'),
#  (0.09324244222298012, 'area_worst'),
#  (0.07438807755306805, 'radius_worst'),
#  (0.05308984039184771, 'radius_mean'),
#  (0.05235355068985064, 'perimeter_mean'),
#  (0.04279763506776049, 'concavity_worst'),
#  (0.0364707920613228, 'area_mean'),
#  (0.03489504313699199, 'concavity_mean'),
#  (0.03456436308766094, 'area_se'),
#  (0.020721134681321942, 'texture_worst'),
#  (0.01650832293430531, 'compactness_worst'),
#  (0.01610284263696132, 'texture_mean'),
#  (0.013575500999546446, 'compactness_mean'),
#  (0.012798966394654497, 'symmetry_worst'),
#  (0.012103957252866232, 'radius_se'),
#  (0.01175308110206966, 'smoothness_worst'),
#  (0.011430226726020504, 'perimeter_se'),
#  (0.00798267144307205, 'fractal_dimension_worst'),
#  (0.007458220990570214, 'smoothness_mean'),
#  (0.00735166493944828, 'concave points_se'),
#  (0.007039441894510172, 'concavity_se'),
#  (0.006586487724153184, 'id'),
#  (0.00638963872110814, 'fractal_dimension_se'),
#  (0.004799224634232482, 'symmetry_se'),
#  (0.0046922295451383225, 'smoothness_se'),
#  (0.00430318564548942, 'texture_se'),
#  (0.004239404640291307, 'fractal_dimension_mean'),
#  (0.0038807093863967583, 'symmetry_mean'),
#  (0.0038751906141924496, 'compactness_se')]
